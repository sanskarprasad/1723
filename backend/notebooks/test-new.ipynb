# %%
import pandas as pd

# %%
df1 = pd.read_csv('/home/nitin/Downloads/SIH-1723/data/raw/WEIGHT_DATA.csv')
df2 = pd.read_csv('/home/nitin/Downloads/SIH-1723/data/raw/wire rod chemical.csv')
df3 = pd.read_csv('/home/nitin/Downloads/SIH-1723/data/raw/wire rod properties.csv')
df4 = pd.read_csv('/home/nitin/Downloads/SIH-1723/data/raw/WRM_2_DATA.csv')

# %%
df1
# Out:
#           id productName  castNo  coilNo  diameter grade  rawWeight  \
# 0     165655    WIRE ROD  858112       7       9.5  WE10       2072
# 1     165656    WIRE ROD  858112       8       9.5  WE10       2072
# 2     165657    WIRE ROD  858112       9       9.5  WE10       2070
# 3     165658    WIRE ROD  858112      10       9.5  WE10       2072
# 4     165659    WIRE ROD  858112      11       9.5  WE10       2069
# ...      ...         ...     ...     ...       ...   ...        ...
# 9980  175630    WIRE ROD  658683      16       9.5   NaN       2077
# 9981  175631    WIRE ROD  858762       6       9.5   NaN       2096
# 9982  175632    WIRE ROD  858762       7       9.5   NaN       2126
# 9983  175633    WIRE ROD  658683      17       9.5   NaN       2075
# 9984  175634    WIRE ROD  658683      18       9.5   NaN       2043
#
#       netWeight  grossWeight  rawDate  netDate grossDate       rawNode  \
# 0        2069.0       2097.0  27:29.0  17:18.0   05:23.0  WRM2-BARCODE
# ...

# %%
df2
# Out:
#      Unnamed: 0  Sl No  Cast Number Posting Date  Stack No Grade  Wt(MT)  Pcs  \
# 0           NaN      1       558097   01.09.2024       NaN  W000  41.056  NaN
# 1           NaN      2       558101   01.09.2024       NaN  W000  36.447  NaN
# 2           NaN      3       558105   02.09.2024       NaN  W000  34.567  NaN
# 3           NaN      4       558109   02.09.2024       NaN  W000  36.465  NaN
# 4           NaN      5       558113   03.09.2024       NaN  W000  26.373  NaN
# ..          ...    ...          ...          ...       ...   ...     ...  ...
# 609         NaN    610       858738   22.11.2024       NaN  W000  22.160  NaN
# 610         NaN    611       858742   23.11.2024       NaN  W000  45.389  NaN
# 611         NaN    612       858746   23.11.2024       NaN  W000  11.913  NaN
# 612         NaN    613       858750   24.11.2024       NaN  W000  39.950  NaN
# 613         NaN    614       858754   24.11.2024       NaN  W000  31.399  NaN
#
# ...

# %%
df3
# Out:
#       Unnamed: 0        Date  Unnamed: 2  Batch No  Diameter Material  Coil  \
# 0            NaN  01.09.2024         NaN    558097        10  W000000     1
# 1            NaN  01.09.2024         NaN    558097        10  W000000    10
# 2            NaN  01.09.2024         NaN    558097        10  W000000    11
# 3            NaN  01.09.2024         NaN    558097        10  W000000    12
# 4            NaN  01.09.2024         NaN    558097        10  W000000    13
# ...          ...         ...         ...       ...       ...      ...   ...
# 9810         NaN  24.11.2024         NaN    858754        10  W000000     5
# 9811         NaN  24.11.2024         NaN    858754        10  W000000     6
# 9812         NaN  24.11.2024         NaN    858754        10  W000000     7
# 9813         NaN  24.11.2024         NaN    858754        10  W000000     8
# 9814         NaN  24.11.2024         NaN    858754        10  W000000     9
#
# ...

# %%
df3['Date'] = pd.to_datetime(df3['Date'], format='%d.%m.%Y')
df3.dtypes
# Out:
# Unnamed: 0                     float64
# Date                    datetime64[ns]
# Unnamed: 2                     float64
# Batch No                         int64
# Diameter                         int64
# Material                        object
# Coil                             int64
# UTS                            float64
# Elongation                     float64
# Conductivity                   float64
# Grade                           object
# Material.1                      object
# Total order quantity            object
# Unnamed: 13                    float64
# dtype: object

# %%
df3.to_csv('/home/nitin/Downloads/SIH-1723/frontend/public/data/wire rod properties.csv',index=False)

# %%
df4
# Out:
#       timestamp timestamp_utc  sequence_number  EMUL_OIL_L_TEMP_PV_VAL0  \
# 0       01:59.4       31:59.4           150793                60.355865
# 1       10:38.8       40:38.8           150794                60.068710
# 2       20:38.9       50:38.9           150795                60.398239
# 3       29:11.8       59:11.8           150796                60.359528
# 4       39:11.9       09:11.9           150797                60.448059
# ...         ...           ...              ...                      ...
# 10921   38:48.5       08:48.5           161714                60.386810
# 10922   39:35.7       09:35.7           161715                60.470840
# 10923   49:35.7       19:35.7           161716                60.334030
# 10924   59:35.7       29:35.7           161717                60.316437
# 10925   00:03.0       30:03.0           161718                60.231827
#
#        STAND_OIL_L_TEMP_PV_REAL_VAL0  GEAR_OIL_L_TEMP_PV_REAL_VAL0  \
# ...
